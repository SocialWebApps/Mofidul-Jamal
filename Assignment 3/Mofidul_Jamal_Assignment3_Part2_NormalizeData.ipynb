# %% [markdown]
# #Assignment 3 - Part 2
# #Normalizing the LinkedIn data
# ##Mofidul I. Jamal
# ##Web 2.0 Architectures & Algorithms
# ##Spring 2015

# %% [markdown]
# ###Normalizing the data
# This file will do the following:
# * Load the file with the LinkedIn data that was written out in part 1
# * Print out this data
# * Perform a custom normalization of the job titles in the data by grouping job titles into roles based on keywords
# * Write out the grouped job titles
# * Print out the statistics on the number of job titles that were normalized and calculate the ratio of job titles which couldn't be normalized with my grouping method

# %% [markdown]
# ###Load the file, print it out

# %%
import json
from prettytable import PrettyTable
#load the file that was written out during part 1
with open('data\\linkedin_connections_data.json') as data_file:
    json_data = json.load(data_file)
    pt = PrettyTable(field_names=['Id', 'Company', 'Title'])
    titles = []
    for entry in json_data:
        #print entry
        if 'values' in entry['positions']:
            for position in entry['positions']['values']:
                if 'name' in position['company']:
                    pt.add_row([entry['id'],position['company']['name'], position['title']])
                    titles.append({'title': position['title'], 'id': entry['id'], 'company': position['company']['name']})

#print it out
print pt
# Out:
# +------------+--------------------------------------------+--------------------------------------------------------+
# |     Id     |                  Company                   |                         Title                          |
# +------------+--------------------------------------------+--------------------------------------------------------+
# | -3VRISJPnQ |       DataCore Software Corporation        |              Vice President Customer Care              |
# | -3VRISJPnQ |             DataCore Software              |    Vice President Emerging Markets LATAM and CANADA    |
# | -3VRISJPnQ |                  DataCore                  |               VP Distribution Operations               |
# | -3VRISJPnQ |       DataCore Software Corporation        |                     VP Operations                      |
# | D3o_4w9sNZ |        Florida Atlantic University         |         Academic Support Services Coordinator          |
# | WcbJ87H4OQ |                 mPWR, LLC                  |               Managing Principal & Owner               |
# | Q7pfhDfeY_ |                   Citrix                   |             Product Manager - HDX Graphics             |
# | 77EBf4YwuU |        Charles Rutenberg Realty LLC        |                    Sales Consultant                    |
# | Ayiu4kmfkv |             DataCore Software              |             Director of Product Marketing              |
# | MwxQBTydWw |                 FCB Global                 |                    Product Manager                     |
# | MwxQBTydWw |                 With Pulp                  |                  Product Manager, CEO                  |
# | bHxaMyUFdg |           On-Ramp Wireless, Inc.           |           Business Dev Manager Latin America           |
# | r_7WlNlpoJ |                   Citrix                   |                   Software Engineer                    |
# | BNRiJsAZZu |             DataCore Software              |          Customer Care/Renewals & ISR Manager          |
# | BNRiJsAZZu |       DataCore Software Corporation        | Product Development/Customer Care/Renewals/ISR Manager |
# | HFtb2BkElq |             DataCore Software              |                  Benefits Specialist                   |
# | segaJKGrNy |              MindSoft Bioware              |                  Cognitive Architect                   |
# | jTfl2SJQxP |                   Citrix                   |              Product Development Manager               |
# | GB2KhzZN2a |        Florida Atlantic University         |                       Professor                        |
# | GB2KhzZN2a |        Florida Atlantic University         |                    Associate Chair                     |
# | sCy2Whe7Tv |                   Fiserv                   |                   IT Project Manager                   |
# | ZKTt0ZzNe5 |               Citrix Systems               |                Staff Software Engineer                 |
# | qX37DOt5A8 |             DataCore Software              |               Technical Support Director               |
# | TPvFmZtw3Q |                   Citrix                   |                  Software Engineer 2                   |
# | Cem54RcQat |               Citrix Systems               |              Staff Software Test Engineer              |
# | ybw4ruItjV |                   Citrix                   |            Lead Translation Project Manager            |
# | EyI-dQhI4M |                   Amazon                   |             Software Development Engineer              |
# | uXKoYBNW6B |             DataCore Software              |                   Software Developer                   |
# | YxmYO7qZDn | Susquehanna International Group, LLP (SIG) |       Regional Data Center Systems Adminsitrator       |
# | 6rIeB73W_v |        Florida Atlantic University         |                  Associate Professor                   |
# | XEzD0xtkbO |          NAI/Merin Hunter Codman           |                  Marketing Assistant                   |
# | XEzD0xtkbO |        Freelance Marketing & Design        |                   Creative Director                    |
# | He1JJ5p9XV |             DataCore Software              |          Junior Software Engineer | R&D Group          |
# | He1JJ5p9XV |              Apertura64, Inc.              |    Photographer/Digital Tech/Freelance Photographer    |
# | He1JJ5p9XV |            POW! Design Studios             |                         Owner                          |
# | OyhPUmRqpZ |                  Airlift                   |                        Founder                         |
# | OyhPUmRqpZ |               Redwood Brands               |                     Founder & CEO                      |
# | FQUp9rByJN |             DataCore Software              |                       IT Manager                       |
# | RLQwUXSWTw |                  Stryker                   |          Software Quality Assurance Engineer           |
# | RLQwUXSWTw |             DataCore Software              |                     Test Engineer                      |
# | fVbqbXWWW0 |             CircleBack Lending             |                   Software Engineer                    |
# | xWJmu8K4zv |            Citrix Systems, Inc.            |        Principal Software Development Engineer         |
# | J4QOHX62-2 |    New England Institute of Technology     |                   Adjunct Instructor                   |
# | J4QOHX62-2 |               IPG Photonics                |               Embedded Software Engineer               |
# | GmHD_JUn_h |        Florida Atlantic University         |              Graduate Teaching Assistant               |
# | GmHD_JUn_h |              SilverLogic LLC               |                    Co-Founder & CEO                    |
# | GmHD_JUn_h |    David Hartmann Software Development     |                   Founder and Owner                    |
# | GmHD_JUn_h |               MoreVisibility               |                  Mobile App Developer                  |
# | GmHD_JUn_h |                   SPH AG                   |                     App Developer                      |
# | GmHD_JUn_h |       Wunderbar Consulting and Sales       |                       Web Design                       |
# | nc3uDSxXin | Expression Analysis (A Quintiles Company)  |                Senior Software Engineer                |
# | kwIyRuVUSQ |              SilverLogic LLC               |                    Co-founder & CEO                    |
# | AaTlXkQQvK |        Florida Atlantic University         |                        Faculty                         |
# | 7TNAM8xLOr |             DataCore Software              |               Software Engineer in Test                |
# | 2w0yuaKzr7 |             DataCore Software              |               People Department Manager                |
# | mbfd532h8c |                   Citrix                   |                 Software Test Engineer                 |
# | 0k3V4liu8G |             DataCore Software              |                Senior Software Engineer                |
# | _2o4GD48GA |                  JPay Inc                  |              Mobile Application Developer              |
# | CF9eqt5rUO |                Wells Fargo                 |                   Service Manager 2                    |
# | WmFxXySACl |             DataCore Software              |            Integration Development Engineer            |
# | rUau1av5T6 |             DataCore Software              |                 Software Test Engineer                 |
# | Hbb0rrLhVj |           ProcessMAP Corporation           |                   Software Developer                   |
# | Hbb0rrLhVj |           Google Play Developer            |            Android / Google Play Developer             |
# | 5Rg8CEZ1RT |             Motorola Solutions             |                 Software Test Engineer                 |
# | zXaEOgpqXK |                 RubyBlanc                  |                    Magento Monster                     |
# | zXaEOgpqXK |            Church Pension Group            |       Ruby Developer and QA Automation Engineer        |
# | zXaEOgpqXK |                Waywire.com                 |                Ruby on Rails Developer                 |
# | zXaEOgpqXK |                withpulp.com                |                 Programmer & Sysadmin                  |
# | ZwXo4YpUZS |               Citrix Systems               |          Staff Software Development Engineer           |
# | Msm_hXodQB |             DataCore Software              |                Senior Software Engineer                |
# | 59Po38O4ao |               SEG Promotions               |           Administrative Assistant/Recruiter           |
# | ixzDtVeJO4 |              Verizon Wireless              |                   RF Design Engineer                   |
# | ixzDtVeJO4 |          Dyna'Dance Dance School           |                     Owner/Teacher                      |
# | BLdiUp911k |           The Execu|Search Group           |         Receptionist/Administrative Assistant          |
# | PwtQAGBDt7 |               SMAKK Studios                |                  Front-End Developer                   |
# | o2NkTfkbIL |                  Tr3life                   |                     Web Developer                      |
# | o2NkTfkbIL |            Freelance Web Design            |                 Freelance Web Designer                 |
# | Z88od12nHs |               Citrix Systems               |          Senior Software Development Engineer          |
# | Nft_lv-u3c |             DataCore Software              |                     Test Engineer                      |
# | d7VFlNloDX |        Aerospace Technologies Group        |                     IT Coordinator                     |
# | S8Y4geqFJs |        Lexmark International, Inc.         |                   Firmware Engineer                    |
# | B0MznA8V-D |           School of Visual Arts            |            Software Developer / Web Master             |
# | B0MznA8V-D |                 With Pulp                  |             Software Wizard and Co-Founder             |
# | amnoKladxU |        Florida Atlantic University         |                        Student                         |
# | amnoKladxU |                 Bosch FHP                  |             Engineering Change Coordinator             |
# | amnoKladxU |                 Bosch FHP                  |               Mechanical Engineer Intern               |
# | 1JSs_KTybl |                   Citrix                   |                 Software Test Engineer                 |
# | PvGnQKJdP3 |                 NxtFactor                  |                Regional Account Manager                |
# | H7hH2drzln |             DataCore Software              |                   Software Engineer                    |
# | b7kTboQqTB |       Good Samaritan Medical Center        |                    Registered Nurse                    |
# | grN6supNM4 |       Digicare Biomedical Technology       |                 Lead Software Engineer                 |
# | pjdPoZrW2q |             Surgical City Inc.             |                     President/CEO                      |
# | ZcvQjwD7Hm |                    RSI                     |                 Sr. Programmer Analyst                 |
# | gZjPY_nUa0 |             DataCore Software              |                 Sr. Software Architect                 |
# | q0r6AmASDd |                   Citrix                   |             Software Development Engineer              |
# | rdEddas7ih |   Comiter, Singer, Baseman, & Braun, LLP   |                   File Administrator                   |
# | wL3AFlJ3mP |         City of Palm Beach Gardens         |               Code Compliance Supervisor               |
# | U2y11_Enzz |                    FAU                     |                    Master's student                    |
# +------------+--------------------------------------------+--------------------------------------------------------+

# %% [markdown]
# ###Find all tokens in job titles
# The following block of code will split all the job titles and find counts for all the tokens (individual words) within all job titles and print them out.
# This list of tokens was used as the basis for selecting the keywords used in the grouping algorithm.

# %%
from collections import Counter
from operator import itemgetter
tokens_first_pass = []
tokens_second_pass = []
#split titles into tokens
titles_only = [row['title'] for row in titles]
for title in titles_only:
    tokens_first_pass.extend([t.strip(',') for t in title.split()])
#further split any tokens that comprise a /
for token in tokens_first_pass:
    tokens_second_pass.extend([t.strip() for t in token.split('/')
                              if len(t) > 1])

pt = PrettyTable(field_names=['Token', 'Freq'])
pt.align = 'l'
c = Counter(tokens_second_pass)
[pt.add_row([token, freq]) 
 for (token, freq) in sorted(c.items(), key=itemgetter(1), reverse=True) 
     if freq > 0 and len(token) > 2] # we only care about freq > 1
print pt
# Out:
# +----------------+------+
# | Token          | Freq |
# +----------------+------+
# | Engineer       | 30   |
# | Software       | 28   |
# | Manager        | 13   |
# | Developer      | 11   |
# | Test           | 8    |
# | Development    | 8    |
# | Product        | 6    |
# | CEO            | 5    |
# | Web            | 4    |
# | Senior         | 4    |
# | Owner          | 4    |
# | Assistant      | 4    |
# | and            | 4    |
# | Director       | 3    |
# | Coordinator    | 3    |
# | Founder        | 3    |
# | Staff          | 3    |
# | Care           | 3    |
# | President      | 3    |
# | Customer       | 3    |
# | Lead           | 2    |
# | Freelance      | 2    |
# | Mobile         | 2    |
# | Project        | 2    |
# | Architect      | 2    |
# | Operations     | 2    |
# | Renewals       | 2    |
# | Sr.            | 2    |
# | Ruby           | 2    |
# | Professor      | 2    |
# | App            | 2    |
# | Design         | 2    |
# | ISR            | 2    |
# | Support        | 2    |
# | Vice           | 2    |
# | Co-Founder     | 2    |
# | Photographer   | 2    |
# | Administrative | 2    |
# | Associate      | 2    |
# | Marketing      | 2    |
# | Regional       | 2    |
# | Programmer     | 2    |
# | Principal      | 2    |
# | Master's       | 1    |
# | Firmware       | 1    |
# | Rails          | 1    |
# | Graduate       | 1    |
# | Systems        | 1    |
# | Markets        | 1    |
# | Designer       | 1    |
# | Service        | 1    |
# | Business       | 1    |
# | Adminsitrator  | 1    |
# | Services       | 1    |
# | Translation    | 1    |
# | Recruiter      | 1    |
# | Change         | 1    |
# | Account        | 1    |
# | Cognitive      | 1    |
# | Graphics       | 1    |
# | Mechanical     | 1    |
# | Emerging       | 1    |
# | Instructor     | 1    |
# | Magento        | 1    |
# | HDX            | 1    |
# | Adjunct        | 1    |
# | Department     | 1    |
# | Master         | 1    |
# | Teaching       | 1    |
# | Android        | 1    |
# | Assurance      | 1    |
# | CANADA         | 1    |
# | Latin          | 1    |
# | Registered     | 1    |
# | R&D            | 1    |
# | America        | 1    |
# | Junior         | 1    |
# | Distribution   | 1    |
# | Administrator  | 1    |
# | Supervisor     | 1    |
# | People         | 1    |
# | Chair          | 1    |
# | Group          | 1    |
# | Managing       | 1    |
# | Creative       | 1    |
# | LATAM          | 1    |
# | Specialist     | 1    |
# | Play           | 1    |
# | Automation     | 1    |
# | Data           | 1    |
# | Front-End      | 1    |
# | Wizard         | 1    |
# | Benefits       | 1    |
# | Center         | 1    |
# | Dev            | 1    |
# | Academic       | 1    |
# | Code           | 1    |
# | Application    | 1    |
# | Sales          | 1    |
# | Analyst        | 1    |
# | Engineering    | 1    |
# | Co-founder     | 1    |
# | Digital        | 1    |
# | Integration    | 1    |
# | Nurse          | 1    |
# | Sysadmin       | 1    |
# | Monster        | 1    |
# | Intern         | 1    |
# | Student        | 1    |
# | Faculty        | 1    |
# | Teacher        | 1    |
# | Compliance     | 1    |
# | Embedded       | 1    |
# | Technical      | 1    |
# | Consultant     | 1    |
# | student        | 1    |
# | Google         | 1    |
# | Receptionist   | 1    |
# | File           | 1    |
# | Tech           | 1    |
# | Quality        | 1    |
# +----------------+------+

# %% [markdown]
# ###Group job titles into roles based on keywords
# The following block of code will iterate through all the job titles and try to match each job title to a possible job role based on a keyword search. The keywords that are searched for were hand picked from the token list. Finally the findings will be printed out and written to a file called groups_output.txt

# %%
#we will normalize the titles by grouping them based on keywords
groupings = [
    {'name': 'Engineering/Development', 'keywords': ['Engineer', 'Software', 'Development', 'Architect', 'Developer', 'Programmer', 'Engineering']},
    {'name': 'Management', 'keywords': ['Manager', 'Director', 'Coordinator', 'Supervisor', 'Managing', 'Administrative']},
    {'name': 'Leadership', 'keywords': ['CEO', 'COO', 'CTO', 'CFO', 'VP', 'Vice', 'President', 'Owner', 'Founder', 'Co-Founder', 'Chair']},
    {'name': 'Education', 'keywords': ['Professor', 'Graduate', 'Teaching', 'Instructor', 'Academic', 'Faculty', 'Teacher', 'Student']},
    {'name': 'Sales', 'keywords': ['Sales', 'ISR']}
    ]

group_table = PrettyTable(field_names=['Group', 'Title', 'Company'])
matched_titles = []
for group in groupings:
    group_name = group['name']
    group_keywords = group['keywords']
    for row in titles:
        if any(keyword in row['title'] for keyword in group_keywords):
            group_table.add_row([group_name, row['title'], row['company']])
            matched_titles.append((row['title'], row['company']))
print group_table

#write pretty table output to file
table_txt = group_table.get_string()
with open('groups_output.txt','w') as file:
    file.write(table_txt)
# Out:
# +-------------------------+--------------------------------------------------------+-------------------------------------------+
# |          Group          |                         Title                          |                  Company                  |
# +-------------------------+--------------------------------------------------------+-------------------------------------------+
# | Engineering/Development |                   Software Engineer                    |                   Citrix                  |
# | Engineering/Development | Product Development/Customer Care/Renewals/ISR Manager |       DataCore Software Corporation       |
# | Engineering/Development |                  Cognitive Architect                   |              MindSoft Bioware             |
# | Engineering/Development |              Product Development Manager               |                   Citrix                  |
# | Engineering/Development |                Staff Software Engineer                 |               Citrix Systems              |
# | Engineering/Development |                  Software Engineer 2                   |                   Citrix                  |
# | Engineering/Development |              Staff Software Test Engineer              |               Citrix Systems              |
# | Engineering/Development |             Software Development Engineer              |                   Amazon                  |
# | Engineering/Development |                   Software Developer                   |             DataCore Software             |
# | Engineering/Development |          Junior Software Engineer | R&D Group          |             DataCore Software             |
# | Engineering/Development |          Software Quality Assurance Engineer           |                  Stryker                  |
# | Engineering/Development |                     Test Engineer                      |             DataCore Software             |
# | Engineering/Development |                   Software Engineer                    |             CircleBack Lending            |
# | Engineering/Development |        Principal Software Development Engineer         |            Citrix Systems, Inc.           |
# | Engineering/Development |               Embedded Software Engineer               |               IPG Photonics               |
# | Engineering/Development |                  Mobile App Developer                  |               MoreVisibility              |
# | Engineering/Development |                     App Developer                      |                   SPH AG                  |
# | Engineering/Development |                Senior Software Engineer                | Expression Analysis (A Quintiles Company) |
# | Engineering/Development |               Software Engineer in Test                |             DataCore Software             |
# | Engineering/Development |                 Software Test Engineer                 |                   Citrix                  |
# | Engineering/Development |                Senior Software Engineer                |             DataCore Software             |
# | Engineering/Development |              Mobile Application Developer              |                  JPay Inc                 |
# | Engineering/Development |            Integration Development Engineer            |             DataCore Software             |
# | Engineering/Development |                 Software Test Engineer                 |             DataCore Software             |
# | Engineering/Development |                   Software Developer                   |           ProcessMAP Corporation          |
# | Engineering/Development |            Android / Google Play Developer             |           Google Play Developer           |
# | Engineering/Development |                 Software Test Engineer                 |             Motorola Solutions            |
# | Engineering/Development |       Ruby Developer and QA Automation Engineer        |            Church Pension Group           |
# | Engineering/Development |                Ruby on Rails Developer                 |                Waywire.com                |
# | Engineering/Development |                 Programmer & Sysadmin                  |                withpulp.com               |
# | Engineering/Development |          Staff Software Development Engineer           |               Citrix Systems              |
# | Engineering/Development |                Senior Software Engineer                |             DataCore Software             |
# | Engineering/Development |                   RF Design Engineer                   |              Verizon Wireless             |
# | Engineering/Development |                  Front-End Developer                   |               SMAKK Studios               |
# | Engineering/Development |                     Web Developer                      |                  Tr3life                  |
# | Engineering/Development |          Senior Software Development Engineer          |               Citrix Systems              |
# | Engineering/Development |                     Test Engineer                      |             DataCore Software             |
# | Engineering/Development |                   Firmware Engineer                    |        Lexmark International, Inc.        |
# | Engineering/Development |            Software Developer / Web Master             |           School of Visual Arts           |
# | Engineering/Development |             Software Wizard and Co-Founder             |                 With Pulp                 |
# | Engineering/Development |             Engineering Change Coordinator             |                 Bosch FHP                 |
# | Engineering/Development |               Mechanical Engineer Intern               |                 Bosch FHP                 |
# | Engineering/Development |                 Software Test Engineer                 |                   Citrix                  |
# | Engineering/Development |                   Software Engineer                    |             DataCore Software             |
# | Engineering/Development |                 Lead Software Engineer                 |       Digicare Biomedical Technology      |
# | Engineering/Development |                 Sr. Programmer Analyst                 |                    RSI                    |
# | Engineering/Development |                 Sr. Software Architect                 |             DataCore Software             |
# | Engineering/Development |             Software Development Engineer              |                   Citrix                  |
# |        Management       |         Academic Support Services Coordinator          |        Florida Atlantic University        |
# |        Management       |               Managing Principal & Owner               |                 mPWR, LLC                 |
# |        Management       |             Product Manager - HDX Graphics             |                   Citrix                  |
# |        Management       |             Director of Product Marketing              |             DataCore Software             |
# |        Management       |                    Product Manager                     |                 FCB Global                |
# |        Management       |                  Product Manager, CEO                  |                 With Pulp                 |
# |        Management       |           Business Dev Manager Latin America           |           On-Ramp Wireless, Inc.          |
# |        Management       |          Customer Care/Renewals & ISR Manager          |             DataCore Software             |
# |        Management       | Product Development/Customer Care/Renewals/ISR Manager |       DataCore Software Corporation       |
# |        Management       |              Product Development Manager               |                   Citrix                  |
# |        Management       |                   IT Project Manager                   |                   Fiserv                  |
# |        Management       |               Technical Support Director               |             DataCore Software             |
# |        Management       |            Lead Translation Project Manager            |                   Citrix                  |
# |        Management       |                   Creative Director                    |        Freelance Marketing & Design       |
# |        Management       |                       IT Manager                       |             DataCore Software             |
# |        Management       |               People Department Manager                |             DataCore Software             |
# |        Management       |                   Service Manager 2                    |                Wells Fargo                |
# |        Management       |           Administrative Assistant/Recruiter           |               SEG Promotions              |
# |        Management       |         Receptionist/Administrative Assistant          |           The Execu|Search Group          |
# |        Management       |                     IT Coordinator                     |        Aerospace Technologies Group       |
# |        Management       |             Engineering Change Coordinator             |                 Bosch FHP                 |
# |        Management       |                Regional Account Manager                |                 NxtFactor                 |
# |        Management       |               Code Compliance Supervisor               |         City of Palm Beach Gardens        |
# |        Leadership       |              Vice President Customer Care              |       DataCore Software Corporation       |
# |        Leadership       |    Vice President Emerging Markets LATAM and CANADA    |             DataCore Software             |
# |        Leadership       |               VP Distribution Operations               |                  DataCore                 |
# |        Leadership       |                     VP Operations                      |       DataCore Software Corporation       |
# |        Leadership       |               Managing Principal & Owner               |                 mPWR, LLC                 |
# |        Leadership       |                  Product Manager, CEO                  |                 With Pulp                 |
# |        Leadership       |                    Associate Chair                     |        Florida Atlantic University        |
# |        Leadership       |                         Owner                          |            POW! Design Studios            |
# |        Leadership       |                        Founder                         |                  Airlift                  |
# |        Leadership       |                     Founder & CEO                      |               Redwood Brands              |
# |        Leadership       |                    Co-Founder & CEO                    |              SilverLogic LLC              |
# |        Leadership       |                   Founder and Owner                    |    David Hartmann Software Development    |
# |        Leadership       |                    Co-founder & CEO                    |              SilverLogic LLC              |
# |        Leadership       |                     Owner/Teacher                      |          Dyna'Dance Dance School          |
# |        Leadership       |             Software Wizard and Co-Founder             |                 With Pulp                 |
# |        Leadership       |                     President/CEO                      |             Surgical City Inc.            |
# |        Education        |         Academic Support Services Coordinator          |        Florida Atlantic University        |
# |        Education        |                       Professor                        |        Florida Atlantic University        |
# |        Education        |                  Associate Professor                   |        Florida Atlantic University        |
# |        Education        |                   Adjunct Instructor                   |    New England Institute of Technology    |
# |        Education        |              Graduate Teaching Assistant               |        Florida Atlantic University        |
# |        Education        |                        Faculty                         |        Florida Atlantic University        |
# |        Education        |                     Owner/Teacher                      |          Dyna'Dance Dance School          |
# |        Education        |                        Student                         |        Florida Atlantic University        |
# |          Sales          |                    Sales Consultant                    |        Charles Rutenberg Realty LLC       |
# |          Sales          |          Customer Care/Renewals & ISR Manager          |             DataCore Software             |
# |          Sales          | Product Development/Customer Care/Renewals/ISR Manager |       DataCore Software Corporation       |
# +-------------------------+--------------------------------------------------------+-------------------------------------------+

# %% [markdown]
# ###Determine what wasn't matched
# The following block of code will determine which job titles were not able to be matched by the grouping algorithm and provide a number which details the percent of the original data which was able to be matched, as well as print out the job titles which failed to be matched.

# %%
#the following is a little piece of code i used to output the unmatched titles
#basically i convert all the matched titles into a set
#and then get a set of my original titles
#perform a difference and output any titles that were not matched
matched_titles_set = set(matched_titles)
titles_set = set([(row['title'], row['company']) for row in titles])
missed_set = titles_set - matched_titles_set
print "Non matched titles:"
non_match_table = PrettyTable(field_names=['Title', 'Company'])
for element in missed_set:
    non_match_table.add_row([element[0], element[1]])
print non_match_table
print """Grouping was able to match %d titles out of a total of %d titles. 
This means that %.2f%% of all titles were matched with the 
grouping algorithm as presented here.""" % (len(matched_titles_set), len(titles_set), (float(len(matched_titles_set)) /len(titles_set))*100.0)
# Out:
# Non matched titles:
# +--------------------------------------------------+--------------------------------------------+
# |                      Title                       |                  Company                   |
# +--------------------------------------------------+--------------------------------------------+
# | Photographer/Digital Tech/Freelance Photographer |              Apertura64, Inc.              |
# |                 Magento Monster                  |                 RubyBlanc                  |
# |               Marketing Assistant                |          NAI/Merin Hunter Codman           |
# |               Benefits Specialist                |             DataCore Software              |
# |                File Administrator                |   Comiter, Singer, Baseman, & Braun, LLP   |
# |                 Master's student                 |                    FAU                     |
# |                    Web Design                    |       Wunderbar Consulting and Sales       |
# |                 Registered Nurse                 |       Good Samaritan Medical Center        |
# |    Regional Data Center Systems Adminsitrator    | Susquehanna International Group, LLP (SIG) |
# |              Freelance Web Designer              |            Freelance Web Design            |
# +--------------------------------------------------+--------------------------------------------+
# Grouping was able to match 85 titles out of a total of 95 titles.
# This means that 89.47% of all titles were matched with the
# grouping algorithm as presented here.
